# %% [markdown]
# # Learning Sandbox for LangChain
#
# This notebook will be an environment for learning how to use LangChain and building RAG.

# %% [markdown]
# ## Install Dependencies

# %%
pip install python-dotenv langchain[openai]
# Out:
# Requirement already satisfied: python-dotenv in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain[openai] in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain[openai]) (1.0.2)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain[openai]) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain[openai]) (2.12.3)
# Collecting langchain-openai (from langchain[openai])
#   Downloading langchain_openai-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain[openai]) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai->langchain[openai])
#   Downloading openai-2.6.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai->langchain[openai])
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (4.11.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai])
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai])
#   Downloading jiter-0.11.1-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai])
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai])
#   Downloading regex-2025.10.23-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (3.11)
# Requirement already satisfied: certifi in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain[openai]) (2.5.0)
# Requirement already satisfied: colorama in c:\users\tyler\coding projects\ml-notebooks\venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (0.4.6)
# Downloading langchain_openai-1.0.1-py3-none-any.whl (81 kB)
# Downloading openai-2.6.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 32.1 MB/s eta 0:00:00
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    --------------------------------------- 879.1/879.1 kB 38.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.11.1-cp313-cp313-win_amd64.whl (203 kB)
# Downloading regex-2025.10.23-cp313-cp313-win_amd64.whl (276 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
# Successfully installed distro-1.9.0 jiter-0.11.1 langchain-openai-1.0.1 openai-2.6.1 regex-2025.10.23 tiktoken-0.12.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# OpenAI API Key
from dotenv import load_dotenv
import os
from langchain.chat_models import init_chat_model

load_dotenv()
openai_api_key = os.getenv("openai_api_key")
